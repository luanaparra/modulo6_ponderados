# %% [markdown]
# Inicialmente, instalamos a biblioteca ultralytics.

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached ultralytics-8.0.110-py3-none-any.whl (592 kB)
# ...

# %% [markdown]
# Posteoriormente, foi utilizado o dataset pronto do Roboflow para detectar rachaduras.

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="xtBJvp0oDgsUJam55rL5")
project = rf.workspace("university-bswxt").project("crack-bphdr")
dataset = project.version(2).download("yolov8")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 kB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 11.8 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.2 MB/s eta 0:00:00
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9657 sha256=771cee5ea5ec841081ba29f8105e453c06a1342346e7050b945a1c6408003546
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
# ...

# %% [markdown]
# Por fim, treinamos o modelo com o auxílio do YOLOv8. (com uma duração de 15 minutos)

# %%
# !yolo train data=/content/crack-2/data.yaml model=sample_data/yolov8n.pt epochs=10 lr0=0.01
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 6.96MB/s]
# Ultralytics YOLOv8.0.110 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
